# %% [markdown]
# # **Selección de semilla**

# %% [markdown]
# # *Gráfico de clientes vs semillas*

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Crear un DataFrame a partir de los datos
data = {
    'Clientes': [9000, 9500, 10000, 10500, 11000, 11500, 12000, 12500, 13000],
    's_881207': [84.791, 84.114, 86.214, 86.471, 88.384, 90.344, 90.694, 89.597, 88.687],
    's_881219': [83.834, 84.021, 84.277, 85.491, 87.427, 89.737, 90.344, 90.927, 89.971],
    's_881233': [84.954, 82.621, 82.574, 87.287, 88.944, 89.247, 91.301, 90.811, 93.727],
    's_881249': [82.714, 81.851, 84.137, 85.561, 88.454, 91.044, 88.431, 88.967, 87.241],
    's_881269': [81.944, 85.211, 86.284, 89.131, 90.484, 88.547, 86.751, 87.147, 87.941],
}

df = pd.DataFrame(data)

# Graficar
plt.figure(figsize=(10, 6))
for column in df.columns[1:]:
    plt.plot(df['Clientes'], df[column], marker='o', label=column)

# Etiquetas y título
plt.title('Retención de Clientes')
plt.xlabel('Clientes')
plt.ylabel('Valores')
plt.legend(title='Semillas')
plt.grid()

# Mostrar el gráfico
plt.show()
